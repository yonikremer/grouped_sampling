# %% [markdown]
# <a href="https://colab.research.google.com/github/yonikremer/final_project/blob/master/evaluation/run_evaluation_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, sys, shutil

if os.path.exists("/content/final_project") and os.path.isdir("/content/final_project"):
    shutil.rmtree("/content/final_project")
os.system("git clone https://github.com/yonikremer/final_project.git");

# %pip install -q -r /content/final_project/project_requirements.txt;
# %pip install -q -r /content/final_project/evaluation/evaluation_requirements.txt;

if not os.path.exists("/content/final_project/evaluation/comet_ml_api_key.txt"):
    with open("/content/final_project/evaluation/comet_ml_api_key.txt", 'w') as f:
        f.write("yNLPmFeYvfF9HArNCZ2xm8RHn")

sys.path.append('/content/final_project');

# %run /content/final_project/evaluation/evaluate_translation.py
# Out:
#      |████████████████████████████████| 5.3 MB 37.7 MB/s
#      |████████████████████████████████| 7.6 MB 58.3 MB/s
#      |████████████████████████████████| 163 kB 72.6 MB/s
#      |████████████████████████████████| 72 kB 30 kB/s
#      |████████████████████████████████| 441 kB 60.8 MB/s
#      |████████████████████████████████| 60 kB 7.9 MB/s
#      |████████████████████████████████| 412 kB 70.5 MB/s
#      |████████████████████████████████| 212 kB 59.1 MB/s
#      |████████████████████████████████| 115 kB 71.5 MB/s
#      |████████████████████████████████| 127 kB 71.7 MB/s
#      |████████████████████████████████| 54 kB 3.1 MB/s
#      |████████████████████████████████| 54 kB 2.9 MB/s
#      |████████████████████████████████| 498 kB 63.5 MB/s
#      |████████████████████████████████| 166 kB 72.4 MB/s
#      |████████████████████████████████| 166 kB 54.0 MB/s
#      |████████████████████████████████| 162 kB 74.2 MB/s
#      |████████████████████████████████| 162 kB 72.2 MB/s
#      |████████████████████████████████| 158 kB 75.1 MB/s
#      |████████████████████████████████| 157 kB 70.2 MB/s
#      |████████████████████████████████| 157 kB 78.3 MB/s
#      |████████████████████████████████| 157 kB 72.8 MB/s
#      |████████████████████████████████| 157 kB 77.1 MB/s
#      |████████████████████████████████| 157 kB 75.7 MB/s
#      |████████████████████████████████| 157 kB 60.3 MB/s
#      |████████████████████████████████| 157 kB 76.1 MB/s
#      |████████████████████████████████| 156 kB 78.0 MB/s
#      |████████████████████████████████| 115 kB 71.2 MB/s
#   Building wheel for configobj (setup.py) ... done
# Downloading:   0%|          | 0.00/685 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/651 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/441 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/251M [00:00<?, ?B/s]
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: tensorboard, tensorflow, torch, keras, sklearn. Metrics and hyperparameters can still be logged using comet_ml.log_metrics() and comet_ml.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# starting experiment
# COMET ERROR: Failed to calculate active processors count. Fall back to default CPU count 1
# COMET INFO: Experiment is live on comet.com https://www.comet.com/yonikremer/grouped-sampling-evaluation/2a35188a52324913b3781b836e619e92
# Downloading builder script:   0%|          | 0.00/5.36k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/116k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/3.00k [00:00<?, ?B/s]
# Downloading and preparing dataset news_commentary/ar-cs (download: 15.49 MiB, generated: 49.16 MiB, post-processed: Unknown size, total: 64.65 MiB) to /root/.cache/huggingface/datasets/news_commentary/ar-cs/11.0.0/cfab724ce975dc2da51cdae45302389860badc88b74db8570d561ced6004f8b4...
# Downloading data:   0%|          | 0.00/16.2M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/52128 [00:00<?, ? examples/s]
# Dataset news_commentary downloaded and prepared to /root/.cache/huggingface/datasets/news_commentary/ar-cs/11.0.0/cfab724ce975dc2da51cdae45302389860badc88b74db8570d561ced6004f8b4. Subsequent calls will reuse this data.
#   0%|          | 0/52128 [00:00<?, ?ex/s]
# Downloading builder script:   0%|          | 0.00/7.95k [00:00<?, ?B/s]
#   0%|          | 5/52128 [10:32<2351:25:59, 162.41s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /content/final_project/evaluation/evaluate_translation.py in <module>
#     125
#     126 if __name__ == "__main__":
# --> 127     main()
#
# /content/final_project/evaluation/evaluate_translation.py in main()
#     121     for curr_text_generator in generate_text_generators():
#     122         print("starting experiment")
# --> 123         run_experiment(curr_text_generator)
#     124
#     125
#
# /content/final_project/evaluation/evaluate_translation.py in run_experiment(generator)
#     109         my_evaluator.METRIC_KWARGS = {"lang": language2}
#     110         scores1 = my_evaluator.compute(model_or_pipeline=generator,
# --> 111                                        data=processed_sub_set, input_column=language1, label_column=language2)
#     112         handler.log_sub_experiment(scores1)
#     113         my_evaluator.METRIC_KWARGS = {"lang": language1}
#
# /usr/local/lib/python3.7/dist-packages/evaluate/evaluator/text2text_generation.py in compute(self, model_or_pipeline, data, subset, split, metric, tokenizer, strategy, confidence_level, n_resamples, device, random_state, input_column, label_column, generation_kwargs)
#     246             random_state=random_state,
#     247             input_column=input_column,
# --> 248             label_column=label_column,
#     249         )
#     250
#
# /usr/local/lib/python3.7/dist-packages/evaluate/evaluator/text2text_generation.py in compute(self, model_or_pipeline, data, subset, split, metric, tokenizer, strategy, confidence_level, n_resamples, device, random_state, input_column, label_column, generation_kwargs)
#     105             random_state=random_state,
#     106             input_column=input_column,
# --> 107             label_column=label_column,
#     108         )
#     109
#
# /usr/local/lib/python3.7/dist-packages/evaluate/evaluator/base.py in compute(self, model_or_pipeline, data, subset, split, metric, tokenizer, feature_extractor, strategy, confidence_level, n_resamples, device, random_state, input_column, label_column, label_mapping)
#     253
#     254         # Compute predictions
# --> 255         predictions, perf_results = self.call_pipeline(pipe, pipe_inputs)
#     256         predictions = self.predictions_processor(predictions, label_mapping)
#     257
#
# /usr/local/lib/python3.7/dist-packages/evaluate/evaluator/base.py in call_pipeline(self, pipe, *args, **kwargs)
#     445     def call_pipeline(self, pipe, *args, **kwargs):
#     446         start_time = perf_counter()
# --> 447         pipe_output = pipe(*args, **kwargs, **self.PIPELINE_KWARGS)
#     448         end_time = perf_counter()
#     449         return pipe_output, self._compute_time_perf(start_time, end_time, len(pipe_output))
#
# /content/final_project/text_generator.py in __call__(self, prompt_s, max_new_tokens, return_tensors, return_text, return_full_text, clean_up_tokenization_spaces, prefix, num_return_sequences, truncation)
#     309                 return_full_text=return_full_text,
#     310                 clean_up_tokenization_spaces=clean_up_tokenization_spaces,
# --> 311                 truncation=truncation) for prompt in tqdm(prompt_s)]
#     312
#     313         curr_token_list: List[int] = self.preprocess(
#
# /content/final_project/text_generator.py in <listcomp>(.0)
#     309                 return_full_text=return_full_text,
#     310                 clean_up_tokenization_spaces=clean_up_tokenization_spaces,
# --> 311                 truncation=truncation) for prompt in tqdm(prompt_s)]
#     312
#     313         curr_token_list: List[int] = self.preprocess(
#
# /content/final_project/text_generator.py in __call__(self, prompt_s, max_new_tokens, return_tensors, return_text, return_full_text, clean_up_tokenization_spaces, prefix, num_return_sequences, truncation)
#     321             curr_token_list,
#     322             max_new_tokens,
# --> 323             num_return_sequences
#     324         )
#     325
#
# /content/final_project/sampling_generator.py in _forward(self, tokenized_prompt, num_new_tokens, num_return_sequences)
#     210                 the_range = range(num_groups)
#     211             for _ in the_range:
# --> 212                 prob_mat = self.get_prob_mat(curr_token_list)
#     213                 new_tokens = self.generate_group(
#     214                     prob_mat, curr_token_list)
#
# /content/final_project/text_generator.py in get_prob_mat(self, token_list)
#     125
#     126         with no_grad():
# --> 127             outputs = self.model(**inputs)
#     128
#     129         logits_tensor = outputs.logits.squeeze(0) / self.temp
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/opt/modeling_opt.py in forward(self, input_ids, attention_mask, head_mask, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#     942             output_attentions=output_attentions,
#     943             output_hidden_states=output_hidden_states,
# --> 944             return_dict=return_dict,
#     945         )
#     946
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/opt/modeling_opt.py in forward(self, input_ids, attention_mask, head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#     703                     past_key_value=past_key_value,
#     704                     output_attentions=output_attentions,
# --> 705                     use_cache=use_cache,
#     706                 )
#     707
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/opt/modeling_opt.py in forward(self, hidden_states, attention_mask, layer_head_mask, output_attentions, use_cache, past_key_value)
#     333             attention_mask=attention_mask,
#     334             layer_head_mask=layer_head_mask,
# --> 335             output_attentions=output_attentions,
#     336         )
#     337         hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=self.training)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/opt/modeling_opt.py in forward(self, hidden_states, key_value_states, past_key_value, attention_mask, layer_head_mask, output_attentions)
#     257         attn_probs = nn.functional.dropout(attn_weights, p=self.dropout, training=self.training)
#     258
# --> 259         attn_output = torch.bmm(attn_probs, value_states)
#     260
#     261         if attn_output.size() != (bsz * self.num_heads, tgt_len, self.head_dim):
#
# KeyboardInterrupt:
